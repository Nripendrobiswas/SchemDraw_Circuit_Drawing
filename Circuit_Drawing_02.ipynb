# %% [markdown]
# <a href="https://colab.research.google.com/github/Nripendrobiswas/SchemDraw_Circuit_Drawing/blob/main/Circuit_Drawing_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install schemdraw

# %%
#############################################################################################
#############################################################################################
### Fig : 9.41                                                                            ###
### Page: 405                                                                             ###
### Book: Fundamentals of Electric Circuits                                               ###
### By Charles K. Alexander & Matthew N.O. Sakidu                                         ###
### 7th Edition                                                                           ###
#############################################################################################
### Name: Nripendro Biswas                                                                ###
### Reg : 2020338058                                                                      ###
#############################################################################################
#############################################################################################


# Using the python package "SchemDraw"
import schemdraw

#To make a circuit diagram, a schemdraw.Drawing and schemdraw.elements is created
import schemdraw.elements as elm    #assigning elements as elm
d = schemdraw.Drawing()             #assigning Drawing as d

#Ciccuit drawing
d.add(elm.SourceV().label('50cos wt V'))
d.add(elm.Resistor().label("2Ω").right())
d.add(elm.Capacitor().label("5mF").down().label("+",ofst=(0.2,1)))
d.add(elm.Inductor2().label("20mH").down().label('$V_{o}$',ofst=(-1.5,1)))
d.add(elm.Line().label("-",ofst=(-2.1,-1)).left())
d.add(elm.Line().up())

#save
d.save('Fig9.41_ElectricCircuit_SadikuPg405_7E.pdf')
#Draw
d.draw()

# %%
#############################################################################################
#############################################################################################                                                                                      ###
### Fig : 9.42                                                                            ###
### Page: 405                                                                             ###
### Book: Fundamentals of Electric Circuits                                               ###
### By Charles K. Alexander & Matthew N.O. Sakidu                                         ###
### 7th Edition                                                                           ###
#############################################################################################
### Name: Nripendro Biswas                                                                ###
### Reg : 2020338058                                                                      ###
#############################################################################################
#############################################################################################



# Using the python package "SchemDraw"
import schemdraw

#To make a circuit diagram, a schemdraw.Drawing and schemdraw.elements is created
import schemdraw.elements as elm    #assigning elements as elm
d = schemdraw.Drawing()             #assigning Drawing as d

#Ciccuit drawing
d.add(elm.SourceV().label("$V_{s}$"))
R=d.add(elm.Resistor().label("10Ω", loc="bottom").right())
d.add(elm.CurrentLabel().scale(0.4).at([0.5,3]).label('$i$'))
d.add(elm.Capacitor().label("5mF").right())
d.add(elm.Inductor2().label("20mH").down())
d.add(elm.Line().left())
d.add(elm.Line().left())

#save
d.save('Fig9.42_ElectricCircuit_SadikuPg405_7E.pdf')
#Draw
d.draw()

# %%
#############################################################################################
#############################################################################################
### Fig : 9.43                                                                            ###
### Page: 406                                                                             ###
### Book: Fundamentals of Electric Circuits                                               ###
### By Charles K. Alexander & Matthew N.O. Sakidu                                         ###
### 7th Edition                                                                           ###
#############################################################################################
### Name: Nripendro Biswas                                                                ###
### Reg : 2020338058                                                                      ###
#############################################################################################
#############################################################################################

# Using the python package "SchemDraw"
import schemdraw

#To make a circuit diagram, a schemdraw.Drawing and schemdraw.elements is created
import schemdraw.elements as elm    #assigning elements as elm
d = schemdraw.Drawing()             #assigning Drawing as d

#Ciccuit drawing
d.add(elm.SourceV().label("$V_{s}$"))
R=d.add(elm.Resistor().label("$R_{1}$").right())
d.add(elm.CurrentLabel().scale(0.4).at([0.5,3]).label('$i$'))
d.push()
d.add(elm.Resistor().label("$R_{2}$").down())
d.pop()
d.add(elm.Inductor2().label("L").right())
d.push()
d.add(elm.Line().right())
d.add(elm.Resistor().label("$R_{3}$").down())
d.add(elm.Line().left())
d.add(elm.Line().left())
d.add(elm.Line().left())
d.pop()
d.add(elm.Capacitor().label("C").down())

#save
d.save('Fig9.43_ElectricCircuit_SadikuPg406_7E.pdf')
#Draw
d.draw()

# %%
#############################################################################################
#############################################################################################                                                                                      ###
### Fig : 9.47                                                                            ###
### Page: 406                                                                             ###
### Book: Fundamentals of Electric Circuits                                               ###
### By Charles K. Alexander & Matthew N.O. Sakidu                                         ###
### 7th Edition                                                                           ###
#############################################################################################
### Name: Nripendro Biswas                                                                ###
### Reg : 2020338058                                                                      ###
#############################################################################################
#############################################################################################

# Using the python package "SchemDraw"
import schemdraw

#To make a circuit diagram, a schemdraw.Drawing and schemdraw.elements is created
import schemdraw.elements as elm         #assigning elements as elm
d = schemdraw.Drawing()                  #assigning Drawing as d

#Ciccuit drawing
d.add(elm.SourceV().label('4 cos wt V','bot'))
R=d.add(elm.Inductor2().label("1H", loc="bottom").right())
d.add(elm.CurrentLabel().scale(0.4).at([0.5,3]).label('$i_{o}$'))
d.push()
d.add(elm.Resistor().label("2Ω").down())
d.pop()
d.add(elm.Line().right())
d.add(elm.Capacitor().label("0.05F").down())
d.add(elm.Line().left())
d.add(elm.Line().left())

#save
d.save('Fig9.47_ElectricCircuit_SadikuPg406_7E.pdf')
#Draw
d.draw()

# %%
#############################################################################################
#############################################################################################                                                                                      ###
### Fig : 9.48                                                                            ###
### Page: 406                                                                             ###
### Book: Fundamentals of Electric Circuits                                               ###
### By Charles K. Alexander & Matthew N.O. Sakidu                                         ###
### 7th Edition                                                                           ###
#############################################################################################
### Name: Nripendro Biswas                                                                ###
### Reg : 2020338058                                                                      ###
#############################################################################################
#############################################################################################

# Using the python package "SchemDraw"
import schemdraw

#To make a circuit diagram, a schemdraw.Drawing and schemdraw.elements is created
import schemdraw.elements as elm         #assigning elements as elm
d = schemdraw.Drawing()                  #assigning Drawing as d

#Ciccuit drawing
d.add(elm.SourceV().label("10 cost V"))
R=d.add(elm.Resistor().label("1Ω").right())
d.push()
d.add(elm.Line().right())
d.add(elm.Capacitor().label("1F").label('+',ofst=(-0.5,0.8)).label('-',ofst=(0.5,0.8)).label("v(t)", loc="bottom").down())
d.add(elm.Line().down())
d.add(elm.Line().left())
d.pop()
d.add(elm.Resistor().label("1Ω").down())
d.add(elm.Inductor2().label("1H").down())
d.add(elm.Line().left())
d.add(elm.Line().up())

#save
d.save('Fig9.48_ElectricCircuit_SadikuPg406_7E.pdf')
#Draw
d.draw()

# %%
#############################################################################################
#############################################################################################                                                                                      ###
### Fig : 9.55                                                                            ###
### Page: 407                                                                             ###
### Book: Fundamentals of Electric Circuits                                               ###
### By Charles K. Alexander & Matthew N.O. Sakidu                                         ###
### 7th Edition                                                                           ###
#############################################################################################
### Name: Nripendro Biswas                                                                ###
### Reg : 2020338058                                                                      ###
#############################################################################################
#############################################################################################

# Using the python package "SchemDraw"
import schemdraw

#To make a circuit diagram, a schemdraw.Drawing and schemdraw.elements is created
import schemdraw.elements as elm         #assigning elements as elm
d = schemdraw.Drawing()                  #assigning Drawing as d

#Ciccuit drawing
d.add(elm.SourceV().label("$V_{s}(t)$").up())
d.add(elm.Resistor().label("10Ω").right())
d.push()
d.add(elm.Inductor2().label("0.2H").down())
d.pop()
d.add(elm.Resistor().label("30Ω", loc="bottom").right())
R=d.add(elm.Capacitor().label("0.5mF").down())
d.add(elm.CurrentLabel().scale(0.4).at([6.2,2.1]).label("$i_{x}$"))
d.add(elm.Line().left())
d.add(elm.Line().left())


#save
d.save('Fig9.55_ElectricCircuit_SadikuPg407_7E.pdf')
#Draw
d.draw()

# %%
#############################################################################################
#############################################################################################                                                                                      ###
### Fig : 9.56                                                                            ###
### Page: 407                                                                             ###
### Book: Fundamentals of Electric Circuits                                               ###
### By Charles K. Alexander & Matthew N.O. Sakidu                                         ###
### 7th Edition                                                                           ###
#############################################################################################
### Name: Nripendro Biswas                                                                ###
### Reg : 2020338058                                                                      ###
#############################################################################################
#############################################################################################

# Using the python package "SchemDraw"
import schemdraw

#To make a circuit diagram, a schemdraw.Drawing and schemdraw.elements is created
import schemdraw.elements as elm         #assigning elements as elm
d = schemdraw.Drawing()                  #assigning Drawing as d

#Ciccuit drawing
d.add(elm.SourceV().label("$V_{s}$").up())
d.add(elm.Resistor().label("2 Ω").right())
d.push()
d.add(elm.Inductor2().label("j2 Ω").down())
d.pop()
R=d.add(elm.Resistor().label("1 Ω", loc="bottom").right())
d.add(elm.CurrentLabel().scale(0.4).at([3.5,3]).label("$i_{x}$"))
d.add(elm.Capacitor().label("-j1Ω").down())
d.add(elm.Line().left())
d.add(elm.Line().left())

#save
d.save('Fig9.56_ElectricCircuit_SadikuPg407_7E.pdf')
#Draw
d.draw()

# %%
#############################################################################################
#############################################################################################                                                                                      ###
### Fig : 9.65                                                                            ###
### Page: 408                                                                             ###
### Book: Fundamentals of Electric Circuits                                               ###
### By Charles K. Alexander & Matthew N.O. Sakidu                                         ###
### 7th Edition                                                                           ###
#############################################################################################
### Name: Nripendro Biswas                                                                ###
### Reg : 2020338058                                                                      ###
#############################################################################################
#############################################################################################

# Using the python package "SchemDraw"
import schemdraw

#To make a circuit diagram, a schemdraw.Drawing and schemdraw.elements is created
import schemdraw.elements as elm         #assigning elements as elm
d = schemdraw.Drawing()                  #assigning Drawing as d

#Ciccuit drawing
d.add(elm.Dot(open=True))
d.add(elm.Line().right())
d.push()
d.add(elm.Line().right())
d.add(elm.Inductor2().label("L",'bot').down())
d.add(elm.Resistor().label("$R_{2}$",'bot').down())
d.add(elm.Line().left())
d.add(elm.Line().left())
d.add(elm.Dot(open=True))
d.pop()
d.add(elm.Resistor().label("$R_{1}$",'bot').down())
d.add(elm.Capacitor().label("C",'bot').down())

#save
d.save('Fig9.65_ElectricCircuit_SadikuPg408_7E.pdf')
#Draw
d.draw()

# %%
#############################################################################################
#############################################################################################                                                                                      ###
### Fig : 9.88                                                                            ###
### Page: 411                                                                             ###
### Book: Fundamentals of Electric Circuits                                               ###
### By Charles K. Alexander & Matthew N.O. Sakidu                                         ###
### 7th Edition                                                                           ###
#############################################################################################
### Name: Nripendro Biswas                                                                ###
### Reg : 2020338058                                                                      ###
#############################################################################################
#############################################################################################

# Using the python package "SchemDraw"
import schemdraw

#To make a circuit diagram, a schemdraw.Drawing and schemdraw.elements is created
import schemdraw.elements as elm         #assigning elements as elm
d = schemdraw.Drawing()                  #assigning Drawing as d

#Ciccuit drawing
d.add(elm.SourceSin().label("250 Hz",'bot'))
d.add(elm.Capacitor().label("-j20 Ω").right())
d.add(elm.Inductor2().label("j30 Ω").right())
d.add(elm.Resistor().label("120 Ω").right())
d.add(elm.Capacitor().label("-j20 Ω").down())
d.add(elm.Line().left())
d.add(elm.Line().left())
d.add(elm.Line().left())

#save
d.save('Fig9.88_ElectricCircuit_SadikuPg411_7E.pdf')
#Draw
d.draw()

# %%
#############################################################################################
#############################################################################################                                                                                      ###
### Fig : 9.89                                                                            ###
### Page: 411                                                                             ###
### Book: Fundamentals of Electric Circuits                                               ###
### By Charles K. Alexander & Matthew N.O. Sakidu                                         ###
### 7th Edition                                                                           ###
#############################################################################################
### Name: Nripendro Biswas                                                                ###
### Reg : 2020338058                                                                      ###
#############################################################################################
#############################################################################################

# Using the python package "SchemDraw"
import schemdraw

#To make a circuit diagram, a schemdraw.Drawing and schemdraw.elements is created
import schemdraw.elements as elm         #assigning elements as elm
d = schemdraw.Drawing()                  #assigning Drawing as d

#Ciccuit drawing
d.add(elm.Dot(open=True))
d.add(elm.Line().right())
d.push()
d.add(elm.Line().right())
d.add(elm.Resistor().label("10Ω").down())
d.add(elm.Capacitor().label("5mH").down())
d.add(elm.Line().left())
d.add(elm.Line().left())
d.add(elm.Dot(open=True))
d.pop()
d.add(elm.Capacitor().label("C").down())
d.add(elm.Line())

#save
d.save('Fig9.89_ElectricCircuit_SadikuPg411_7E.pdf')
#Draw
d.draw()

# %%
import schemdraw
import schemdraw.elements as elm

# creating the object
d = schemdraw.Drawing()

#drawing the main circuit
# voltage source
d.add(elm.SourceV(label="20cos4t V"))
d.add(elm.Resistor(label="10Ω").right())
d.push()
c=d.add(elm.Capacitor(label="0.1F", loc="right").down())
d.add(elm.CurrentLabel().label("ix").at(c))
d.pop()
d.add(elm.Inductor2(label="1C").right())
d.push()

#the variable current
d.add(elm.SourceControlledI(label="2ix").down())
d.pop()
d.add(elm.Line().right())
d.add(elm.Inductor2(label="0.5H", loc="down").down())
d.add(elm.Line().left())
d.add(elm.Ground().right())
d.add(elm.Line().left())
d.add(elm.Line().left())


d.draw()

# %%
import schemdraw
import schemdraw.elements as elm

# creating the object
d = schemdraw.Drawing()

#voltage source
d.add(elm.SourceI(label="10cos(2t) A"))
d.add(elm.Line().right())
d.push()
d.add(elm.Resistor(label="2Ω").label("+  Vx  -", loc="bottom", rotate=270).down())
d.pop()
d.add(elm.Capacitor(label="0.2C").right())
d.push()
d.add(elm.Inductor2(label="2H").down())
d.pop()
d.add(elm.Resistor(label="4Ω").right())
d.add(elm.SourceControlledV(label="3Vx").down().reverse())
d.add(elm.Line().left())
d.add(elm.Ground().right())
d.add(elm.Line().left())
d.add(elm.Line().left())


d.draw()

# %%
import schemdraw
import schemdraw.elements as elm

# creating the object
d = schemdraw.Drawing()

d.add(elm.SourceV(label="10cos 2t V").up())
d.add(elm.Inductor2(label="2H").right())
d.push()
d.add(elm.SourceI(label="2sin5t A").down().reverse())
d.pop()
d.add(elm.Resistor(label="1Ω").label("+ Vo -", loc="bottom"))
d.push()
d.add(elm.Capacitor(label="0.1F").down())
d.pop()
d.add(elm.Resistor(label="4Ω").right())
d.add(elm.SourceV(label="5V").reverse().down())
d.add(elm.Line().left())
d.add(elm.Line().left())
d.add(elm.Line().left())


d.draw()

# %%
import schemdraw
import schemdraw.elements as elm

# creating the object
d = schemdraw.Drawing()

d.add(elm.SourceV(label="75sin 5t V").up())
d.add(elm.Resistor(label="8Ω").right())
d.push()
d.add(elm.Capacitor(label="0.2F", loc="bottom").label("+ Vo -", loc="bottom", rotate=270).down())
d.pop()
d.add(elm.Line().right())
d.push()
d.add(elm.Inductor2(label="1H").down())
d.pop()
d.add(elm.Line().right())
d.add(elm.SourceI().label("6cos 10t A", loc="bottom").reverse().down())
d.add(elm.Line().left())
d.add(elm.Line().left())
d.add(elm.Line().left())



d.draw()

# %%
import schemdraw
import schemdraw.elements as elm

# creating the object
d = schemdraw.Drawing()

d.add(elm.SourceV(Label="sin 2t V").up())
d.add(elm.Inductor2(label="1H").right())
d.push()
d.add(elm.Resistor(label="1Ω").right())
d.add(elm.SourceV().label("sin10t V", loc="bottom").down().reverse())
d.add(elm.Line().left())
d.add(elm.Line().left())
d.pop()
f1=d.add(elm.Capacitor(label="1F").down())

d.add(elm.CurrentLabel(label="Ix").at(f1))
d.draw()

# %%
import schemdraw
import schemdraw.elements as elm

# creating the object
d = schemdraw.Drawing()

d.add(elm.Dot(open=True, label="b"))
d.add(elm.Line().left())
d.push()
d.add(elm.Line())
d.add(elm.SourceV(label="5cost V").up())
d.add(elm.Resistor(label="1KΩ").right())
d.pop()
d.add(elm.Capacitor(label="1F").up())
d.add(elm.Inductor2(label="1H").right())
d.add(elm.Dot(open=True, label="a"))
d.draw()

# %%
import schemdraw
import schemdraw.elements as elm

# creating the object
d = schemdraw.Drawing()

d.add(elm.Dot(open=True, label="b"))
d.add(elm.Line().left())
d.push()
d.add(elm.Line().left())
d.add(elm.SourceV(label="6cost V").up())
d.add(elm.Capacitor(label="-j2Ω").right())
d.add(elm.Line().right())
d.add(elm.Dot(open=True, label="a"))
d.pop()
d.add(elm.Inductor2(label="j4Ω").up())

d.draw()

# %%
import schemdraw
import schemdraw.elements as elm

# creating the object
d = schemdraw.Drawing()

d.add(elm.SourceV(label="4 cos0 V").up())
d.add(elm.Resistor(label="2Ω").right())
d.push()
d.add(elm.Line().right())
d.add(elm.Inductor2().label("+ Vo -", rotate=270, loc="bottom").down())
d.add(elm.Line().left())
d.add(elm.Line().left())
d.pop()
d.add(elm.Capacitor(label="-j5Ω").down())
d.draw()

# %%
import schemdraw
import schemdraw.elements as elm

# creating the object
d = schemdraw.Drawing()

d.add(elm.SourceV(label="10 cos 4t V").up())
d.add(elm.Resistor(label="4Ω").right())
d.push()
sd=d.add(elm.Inductor2(label="1H").down())
d.add(elm.CurrentLabel(label="Io").at(sd))
d.pop()
d.add(elm.Resistor(label="2Ω").right())
d.add(elm.SourceV(label="8V").reverse().down())
d.add(elm.Line().left())
d.add(elm.Line().left())


d.draw()

# %%
import schemdraw
import schemdraw.elements as elm

# creating the object
d = schemdraw.Drawing()

d.add(elm.SourceV(label="Vs").up())
d.add(elm.Capacitor(label="0.25F").right())
d.add(elm.Resistor(label="2Ω").label("+ Vo -",loc="bottom", rotate=270).down())
d.add(elm.Line().left())

d.draw()

# %%
import schemdraw
import schemdraw.elements as elm

# Create a drawing using the schemdraw library
with schemdraw.Drawing() as d:

    # Set the configuration of object 'd' to use unit 3.
    d.config(unit=3)

    d +=elm.Resistor().label('1Ω')
    d +=elm.Capacitor().down().label('-j1 Ω ').label(['+','$v_o$','-'], loc='bot')
    d +=elm.Line().left()
    d +=elm.SourceV(fill='#8BBBBB').up().label('10∠0°V ')

    # Save the schematic diagram as a PDF file
    d.save('Fig10.43_ElectricCircuit_SadikuPg421_3E.pdf')

# %%
import schemdraw
import schemdraw.elements as elm

# Create a drawing using the schemdraw library
with schemdraw.Drawing() as d:

    # Set the configuration of object 'd' to use unit 3.
    d.config(unit=3)
    d +=elm.SourceI(fill='#8BBBBB').up().label('3∠0°V ')
    d +=elm.Line().right()
    d +=elm.Inductor2(loops=3).down().label('j8 Ω', loc='bot').hold()
    d +=elm.Line().right()
    d +=elm.CurrentLabel(length=0.75, ofst=0.25).down().label('$i_0$',loc='bot')
    d +=elm.Capacitor().down().label('-j2 Ω ',loc='bot')
    d +=elm.Line().left()
    d +=elm.Line().left()

    # Save the schematic diagram as a PDF file
    d.save('Fig10.44_ElectricCircuit_SadikuPg421_3E.pdf')

# %%
import schemdraw
import schemdraw.elements as elm

# Create a drawing using the schemdraw library
with schemdraw.Drawing() as d:

    # Set the configuration of object 'd' to use unit 3.
    d.config(unit=3)
    d +=elm.Inductor2(loops=3).down().label('j6 Ω')
    d +=elm.Line().right()
    d +=elm.SourceI(fill='#8BBBBB').up().label('4∠90°V ').label('$V_0$', loc='right').hold()
    d +=elm.Line().right()
    d +=elm.Capacitor().up().label('-j3 Ω ',loc='bot')
    d +=elm.Line().left()
    d +=elm.Line().left()

    # Save the schematic diagram as a PDF file
    d.save('Fig10.45_ElectricCircuit_SadikuPg421_3E.pdf')

# %%
import schemdraw
import schemdraw.elements as elm

# Create a drawing using the schemdraw library
with schemdraw.Drawing() as d:

    # Set the configuration of object 'd' to use unit 3.
    d.config(unit=3)
    d +=elm.Capacitor().down().label('1F ',loc='bot')
    d +=elm.Line().right().dot(open=True).label('b', 'right').hold()
    d +=elm.Line().left()
    d +=elm.SourceV(fill='#8BBBBB').up().label('5cos t V ')
    d +=elm.Resistor().right().label('1Ω')
    d +=elm.Inductor2(loops=3).right().label('1H').dot(open=True).label('a', 'right')

    # Save the schematic diagram as a PDF file
    d.save('Fig10.48_ElectricCircuit_SadikuPg421_3E.pdf')

# %%
import schemdraw
import schemdraw.elements as elm

# Create a drawing using the schemdraw library
with schemdraw.Drawing() as d:

    # Set the configuration of object 'd' to use unit 3.
    d.config(unit=3)
    d +=elm.Inductor2(loops=3).down().label('j4 Ω ',loc='bot')
    d +=elm.Line().right().dot(open=True).label('b', 'right').hold()
    d +=elm.Line().left()
    d +=elm.SourceV(fill='#8BBBBB').up().label('6∠0°V ')
    d +=elm.Capacitor().right().label('–j2 Ω')
    d +=elm.Line().right().dot(open=True).label('a', 'right')

    # Save the schematic diagram as a PDF file
    d.save('Fig10.49_ElectricCircuit_SadikuPg421_3E.pdf')

# %%
import schemdraw
import schemdraw.elements as elm

# Create a drawing using the schemdraw library
with schemdraw.Drawing() as d:

    # Set the configuration of object 'd' to use unit 3.
    d.config(unit=3)
    d +=elm.SourceV(fill='#8BBBBB').label('10 cos(t – 45°) V ')
    d +=elm.Resistor().right().label('1Ω')
    d +=elm.Capacitor().down().label('1 F ').label(['+','$v_o$','-'], loc='bot').hold()
    d +=elm.Inductor2(loops=3).right().label('1H')
    d +=elm.SourceV(fill='#8BBBBB').down().reverse().label(' 5sin(t + 30°) V ',loc='bot')
    d +=elm.Line().left()
    d +=elm.Line().left()

    # Save the schematic diagram as a PDF file
    d.save('Fig10.50_ElectricCircuit_SadikuPg422_3E.pdf')

# %%
import schemdraw
import schemdraw.elements as elm

# Create a drawing using the schemdraw library
with schemdraw.Drawing() as d:

    # Set the configuration of object 'd' to use unit 3.
    d.config(unit=3)
    d +=elm.SourceV(fill='#8BBBBB').label('16 sin (4t – 10°) V ')
    d +=elm.CurrentLabel(length=0.75, ofst=.3).right().label('$i_x$')
    d +=elm.Inductor2(loops=3).right().label('1H')
    d +=elm.SourceControlledI().down().reverse().label('0.5$i_x$ ', loc='bot').hold()
    d +=elm.Capacitor().right().label('0.25F')
    d +=elm.Resistor().down().label('1  Ω ').label(['+','$v_o$','-'], loc='bot')
    d +=elm.Line().left()
    d +=elm.Line().left()

    # Save the schematic diagram as a PDF file
    d.save('Fig10.53_ElectricCircuit_SadikuPg422_3E.pdf')

# %%
import schemdraw
import schemdraw.elements as elm

# Create a drawing using the schemdraw library
with schemdraw.Drawing() as d:

    # Set the configuration of object 'd' to use unit 3.
    d.config(unit=3)
    d +=elm.SourceV(fill='#8BBBBB').up().label('$V_s$(t) ')
    d +=elm.Resistor().right().label('R')
    d +=elm.Inductor2(loops=3).down().label('L', loc='bot').hold()
    d +=elm.Line().right()
    d +=elm.Capacitor2().down().label('C ').label(['+','$v_o$','-'], loc='bot')
    d +=elm.Line().left()
    d +=elm.Line().left()

    # Save the schematic diagram as a PDF file
    d.save('Fig10.63_ElectricCircuit_SadikuPg424_3E.pdf')

# %%
import schemdraw
import schemdraw.elements as elm

# Create a drawing using the schemdraw library
with schemdraw.Drawing() as d:

    # Set the configuration of object 'd' to use unit 3.
    d.config(unit=3)
    d +=elm.SourceV(fill='#8BBBBB').label('5 cos $10^5$t V ')
    d +=elm.Resistor().right().label('20Ω')
    d +=elm.Capacitor().down().label('0.2 $\mu$F ').hold()
    d +=elm.Inductor2(loops=3).right().label('0.4mH')
    d +=elm.Resistor().down().reverse().label('80 Ω').label(['+','$v_o$','-'], loc='bot')
    d +=elm.Line().left()
    d +=elm.Line().left()

    # Save the schematic diagram as a PDF file
    d.save('Fig10.80_ElectricCircuit_SadikuPg426_3E.pdf')

# %%
import schemdraw
import schemdraw.elements as elm

# Create a drawing using the schemdraw library
with schemdraw.Drawing() as d:

    # Set the configuration of object 'd' to use unit 3.
    d.config(unit=3)
    d +=elm.Inductor2(loops=3).down().label('j20 Ω ',loc='bot')
    d +=elm.Line().right().dot(open=True).hold()
    d +=elm.Line().left()
    d +=elm.Line().left()
    d +=elm.SourceV(fill='#8BBBBB').up().label('60∠120°V ')
    d +=elm.Resistor().right().label('5Ω')
    d +=elm.Capacitor().label('–j10 Ω ')
    d +=elm.Resistor().right().label('2 Ω').dot(open=True)

    # Save the schematic diagram as a PDF file
    d.save('Fig10.85_ElectricCircuit_SadikuPg427_3E.pdf')
